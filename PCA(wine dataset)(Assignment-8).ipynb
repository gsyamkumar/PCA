# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt

# %%
#Reading the dataset
df = pd.read_csv('wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
#Converting the numerical data into z-scores
data_normal = scale(df)
data_normal
# Out:
# array([[-1.21394365,  1.51861254, -0.5622498 , ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [-1.21394365,  0.24628963, -0.49941338, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [-1.21394365,  0.19687903,  0.02123125, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 1.37386437,  0.33275817,  1.74474449, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 1.37386437,  0.20923168,  0.22769377, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.37386437,  1.39508604,  1.58316512, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
pca = PCA(n_components=14)
pca_values =pca.fit_transform(data_normal)
pca_values
# Out:
# array([[-3.52293390e+00, -1.45309844e+00, -1.64795488e-01, ...,
#          5.52927766e-01, -3.02978176e-01,  2.00857450e-01],
#        [-2.52885806e+00,  3.30019252e-01, -2.02670665e+00, ...,
#          3.94971160e-01, -1.46645308e-01,  1.26402355e-01],
#        [-2.78502898e+00, -1.03693595e+00,  9.83237703e-01, ...,
#          1.89799314e-03,  2.12780166e-02, -5.57515155e-02],
#        ...,
#        [ 3.02727243e+00, -2.75604024e+00, -9.40803036e-01, ...,
#          6.93336340e-01,  1.67035660e-01, -3.16957430e-02],
#        [ 2.75522166e+00, -2.29378408e+00, -5.50473677e-01, ...,
#          3.44119826e-01, -1.09514873e-01,  1.02823104e-01],
#        [ 3.49633565e+00, -2.76060799e+00,  1.01315115e+00, ...,
#         -1.89866131e-01, -1.64090011e-01, -2.64916504e-01]])

# %%
#loading weights
pca.components_
# Out:
# array([[ 0.39366953, -0.13632501,  0.22267638, -0.00225793,  0.22429849,
#         -0.12463016, -0.35926404, -0.39071171,  0.2670012 , -0.2790625 ,
#          0.08931829, -0.27682265, -0.35052618, -0.26951525],
#        [-0.00569041, -0.48416087, -0.22359095, -0.31585588,  0.01161574,
#         -0.30055143, -0.06711983,  0.00131345, -0.0269887 , -0.04122256,
#         -0.52978274,  0.27790735,  0.16277625, -0.36605886],
#        [ 0.00121795, -0.20740081,  0.08879606,  0.62610236,  0.6119896 ,
#          0.13098458,  0.14650775,  0.15096275,  0.16997551,  0.14987959,
#         -0.1372663 ,  0.08532854,  0.16620436, -0.12668685],
#        [ 0.12246373, -0.08191848,  0.46988824, -0.24984122,  0.07199322,
#         -0.16321412,  0.19098521,  0.14461667, -0.32801272,  0.46275771,
#          0.07211248, -0.43466618,  0.15672341, -0.2557949 ],
#        [ 0.15758395, -0.25089415, -0.18860015, -0.0935236 ,  0.0465675 ,
# ...

# %%
# The amount of variance that each PCA explains is 
#It explains how much information is present in the variance on each of pca values
 
var = pca.explained_variance_ratio_
var
# Out:
# array([0.39542486, 0.17836259, 0.10329102, 0.06627984, 0.06267875,
#        0.0480556 , 0.03955707, 0.02500244, 0.02103871, 0.01873615,
#        0.01613203, 0.01205691, 0.00925458, 0.00412945])

# %%
#Cumulative variance

#converting the pca values into percentages
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([ 39.54,  57.38,  67.71,  74.34,  80.61,  85.42,  89.38,  91.88,
#         93.98,  95.85,  97.46,  98.67,  99.6 , 100.01])

# %%
#Variance plot for PCA components obtained
plt.plot(var,color= 'b')

# %%
pca_values[:,0:1]
# Out:
# array([[-3.5229339 ],
#        [-2.52885806],
#        [-2.78502898],
#        [-3.92258841],
#        [-1.40751111],
#        [-3.28812981],
#        [-2.75057754],
#        [-2.39286652],
#        [-2.79525633],
#        [-3.00559666],
#        [-3.67868855],
#        [-2.10963477],
#        [-2.43845636],
#        [-3.67349453],
#        [-4.44157575],
#        [-2.60892387],
#        [-2.47542846],
#        [-2.22623243],
#        [-3.74226929],
#        [-2.3944115 ],
#        [-3.33656895],
#        [-1.48140399],
#        [-2.82806867],
#        [-2.00771405],
#        [-2.11463604],
#        [-1.39753751],
#        [-2.13348803],
#        [-1.62970383],
#        [-2.50760753],
#        [-2.55948318],
#        [-2.77244452],
#        [-2.93513374],
#        [-1.99124842],
#        [-2.24570987],
#        [-1.78698628],
#        [-2.22763867],
#        [-1.76802847],
#        [-1.52317798],
#        [-1.87236494],
#        [-2.79711434],
#        [-2.84093569],
# ...

# %%
final = pd.concat([pd.DataFrame(pca_values[:,0:2],columns=['pc1','pc2']),df[['Type']]],axis=1)
final
# Out:
#           pc1       pc2  Type
# 0   -3.522934 -1.453098     1
# 1   -2.528858  0.330019     1
# 2   -2.785029 -1.036936     1
# 3   -3.922588 -2.768210     1
# 4   -1.407511 -0.867773     1
# ..        ...       ...   ...
# 173  3.627996 -2.206617     3
# 174  2.942729 -1.752263     3
# 175  3.027272 -2.756040     3
# 176  2.755222 -2.293784     3
# 177  3.496336 -2.760608     3
#
# [178 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
import seaborn as sns
sns.scatterplot(data=final,x='pc1',y='pc2',hue='Type',s = 100)
# Out:
# <AxesSubplot:xlabel='pc1', ylabel='pc2'>

# %%
p1 = sns.scatterplot(data=final,x='pc1',y='pc2',s = 100)  
for line in range(0,final.shape[0]):
     p1.text(final.pc1[line], final.pc2[line], final.Type[line], horizontalalignment='left', size='medium')

# %% [markdown]
# # Hierarchical Clustering

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('wine.csv')
df1
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
# Normalization
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
df_norm = norm_func(df1.iloc[:,1:])
df_norm
# Out:
#       Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0    0.842105  0.191700  0.572193    0.257732   0.619565  0.627586
# 1    0.571053  0.205534  0.417112    0.030928   0.326087  0.575862
# 2    0.560526  0.320158  0.700535    0.412371   0.336957  0.627586
# 3    0.878947  0.239130  0.609626    0.319588   0.467391  0.989655
# 4    0.581579  0.365613  0.807487    0.536082   0.521739  0.627586
# ..        ...       ...       ...         ...        ...       ...
# 173  0.705263  0.970356  0.582888    0.510309   0.271739  0.241379
# 174  0.623684  0.626482  0.598930    0.639175   0.347826  0.282759
# 175  0.589474  0.699605  0.481283    0.484536   0.543478  0.210345
# 176  0.563158  0.365613  0.540107    0.484536   0.543478  0.231034
# 177  0.815789  0.664032  0.737968    0.716495   0.282609  0.368966
#
#      Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  Dilution  \
# 0      0.573840       0.283019         0.593060  0.372014  0.455285  0.970696
# ...

# %%
#Creating Dendogram using average method
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch 
z = linkage(df_norm, method="average",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(z,)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering 
import warnings 
warnings.filterwarnings('ignore')
h_complete = AgglomerativeClustering(n_clusters=5, linkage='average',affinity = "euclidean").fit(df_norm) 

cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
df1['clust']=cluster_labels # creating a  new column and assigning cluster_labels to new column 
df1
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df1.iloc[:,1:].groupby(df1.clust).mean()
# Out:
#          Alcohol     Malic       Ash  Alcalinity   Magnesium   Phenols  \
# clust
# 0      12.985750  1.902667  2.353083   18.772500  100.241667  2.535417
# 1      13.122830  3.220943  2.413962   21.062264   98.924528  1.706792
# 2      12.370000  0.940000  1.360000   10.600000   88.000000  1.980000
# 3      11.560000  2.050000  3.230000   28.500000  119.000000  3.180000
# 4      12.126667  4.616667  2.113333   20.666667   91.666667  2.886667
#
#        Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  \
# clust
# 0        2.526250       0.322333         1.776000  4.239000  1.072133
# 1        0.833019       0.457170         1.118302  7.083208  0.708679
# 2        0.570000       0.280000         0.420000  1.950000  1.050000
# 3        5.080000       0.470000         1.870000  6.000000  0.930000
# 4        2.753333       0.250000         2.833333  2.766667  0.743333
#
#        Dilution     Proline  clust
# clust
# 0      2.997417  813.650000      0
# ...

# %%
#checking which data is following cluster1
data = df1[(df1.clust==1)]
data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 60      2    12.33   1.10  2.28        16.0        101     2.05        1.09
# 61      2    12.64   1.36  2.02        16.8        100     2.02        1.41
# 68      2    13.34   0.94  2.36        17.0        110     2.53        1.30
# 83      2    13.05   3.86  2.32        22.5         85     1.65        1.59
# 118     2    12.77   3.43  1.98        16.0         80     1.63        1.25
# 130     3    12.86   1.35  2.32        18.0        122     1.51        1.25
# 131     3    12.88   2.99  2.40        20.0        104     1.30        1.22
# 132     3    12.81   2.31  2.40        24.0         98     1.15        1.09
# 133     3    12.70   3.55  2.36        21.5        106     1.70        1.20
# 134     3    12.51   1.24  2.25        17.5         85     2.00        0.58
# 135     3    12.60   2.46  2.20        18.5         94     1.62        0.66
# ...

# %%
#checking which data is following cluster2
data = df1[(df1.clust==2)]
data
# Out:
#     Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 59     2    12.37   0.94  1.36        10.6         88     1.98        0.57
#
#     Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  clust
# 59           0.28             0.42   1.95  1.05      1.82      520      2

# %% [markdown]
# # K-means Clustering

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
#Normalization 
def norm_func(i):
    x =(i-i.min())/(i.max() -i.min())
    return (x)

# %%
df3_norm= norm_func(df.iloc[:,1:])
df3_norm
# Out:
#       Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0    0.842105  0.191700  0.572193    0.257732   0.619565  0.627586
# 1    0.571053  0.205534  0.417112    0.030928   0.326087  0.575862
# 2    0.560526  0.320158  0.700535    0.412371   0.336957  0.627586
# 3    0.878947  0.239130  0.609626    0.319588   0.467391  0.989655
# 4    0.581579  0.365613  0.807487    0.536082   0.521739  0.627586
# ..        ...       ...       ...         ...        ...       ...
# 173  0.705263  0.970356  0.582888    0.510309   0.271739  0.241379
# 174  0.623684  0.626482  0.598930    0.639175   0.347826  0.282759
# 175  0.589474  0.699605  0.481283    0.484536   0.543478  0.210345
# 176  0.563158  0.365613  0.540107    0.484536   0.543478  0.231034
# 177  0.815789  0.664032  0.737968    0.716495   0.282609  0.368966
#
#      Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  Dilution  \
# 0      0.573840       0.283019         0.593060  0.372014  0.455285  0.970696
# ...

# %%
#Creating Elbow curve
fig = plt.figure(figsize=(10,8))
WCSS = []
for i in range(1,11):
    clf = KMeans(n_clusters=i)
    clf.fit(df3_norm)
    WCSS.append(clf.inertia_)#inerita is another name for WCSS and all the calculations are done in background
plt.plot(range(1,11),WCSS)
plt.title("Elbow Curve")
plt.xlabel('WCSS')
plt.ylabel("Number of Clusters")
plt.show()

# %%
clf = KMeans(n_clusters=5)
y_kmeans = clf.fit_predict(df3_norm)

# %%
y_kmeans
# Out:
# array([2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 4, 3, 0, 3, 3,
#        0, 3, 3, 3, 3, 0, 3, 0, 0, 3, 3, 3, 3, 0, 3, 0, 3, 4, 0, 3, 3, 3,
#        3, 3, 3, 3, 3, 0, 0, 2, 3, 3, 0, 0, 3, 3, 0, 3, 3, 3, 3, 3, 3, 0,
#        0, 0, 3, 3, 3, 3, 3, 3, 4, 3, 0, 0, 0, 0, 0, 0, 0, 3, 3, 4, 1, 1,
#        1, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 4, 1, 1, 1, 1, 1, 1,
#        1, 4, 1, 4, 1, 1, 4, 4, 4, 4, 1, 4, 1, 1, 1, 1, 4, 1, 1, 4, 1, 1,
#        1, 1])

# %%
clf.cluster_centers_
# Out:
# array([[0.36598441, 0.34497145, 0.55931868, 0.53398244, 0.29549114,
#         0.63001277, 0.51023597, 0.31865828, 0.49258091, 0.1813614 ,
#         0.42336646, 0.68783069, 0.18650605],
#        [0.58623482, 0.44481605, 0.58350473, 0.56978588, 0.36622074,
#         0.24774536, 0.12869198, 0.48984035, 0.28827954, 0.63865187,
#         0.12914321, 0.11580727, 0.25010973],
#        [0.72025376, 0.23394269, 0.57190604, 0.32078424, 0.40159161,
#         0.64476601, 0.56050332, 0.29380054, 0.47881929, 0.36617808,
#         0.47793264, 0.68792517, 0.61367689],
#        [0.31597307, 0.16655943, 0.44857605, 0.48070007, 0.25758342,
#         0.34506816, 0.2982043 , 0.49495393, 0.32697528, 0.13844353,
#         0.50833806, 0.51017974, 0.17460107],
#        [0.51012146, 0.57745515, 0.54689428, 0.52874703, 0.24916388,
#         0.24323607, 0.08089906, 0.72278665, 0.1784761 , 0.36229982,
#         0.21857411, 0.20907298, 0.2353506 ]])

# %%
clf.inertia_
# Out:
# 42.31236208564799

# %%
md = pd.Series(y_kmeans)
df['clust'] = md
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.iloc[:,1:].groupby(df.clust).mean()
# Out:
#          Alcohol     Malic       Ash  Alcalinity   Magnesium   Phenols  \
# clust
# 0      12.420741  2.485556  2.405926   20.959259   97.185185  2.807037
# 1      13.257692  2.990769  2.451154   21.653846  103.692308  1.698462
# 2      13.766964  1.923750  2.429464   16.823214  106.946429  2.849821
# 3      12.230698  1.582791  2.198837   19.925581   93.697674  1.980698
# 4      12.968462  3.661923  2.382692   20.857692   92.923077  1.685385
#
#        Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  \
# clust
# 0        2.758519       0.298889         1.971481  3.405556  1.000741
# 1        0.950000       0.389615         1.323846  8.765000  0.638846
# 2        2.996786       0.285714         1.927857  5.571607  1.067857
# 3        1.753488       0.392326         1.446512  2.902558  1.105256
# 4        0.723462       0.513077         0.975769  5.526154  0.748846
#
#        Dilution      Proline  clust
# clust
# 0      3.147778   539.481481      0
# ...

# %%
df.plot(x="Alcohol",y ="Malic",c=clf.labels_,kind="scatter",s=50 ,cmap=plt.cm.coolwarm) 
plt.title('Clusters using KMeans')
# Out:
# Text(0.5, 1.0, 'Clusters using KMeans')

# %%
WCSS
# Out:
# [95.5995377847106,
#  64.53766702389431,
#  48.9605171366765,
#  44.76933054082478,
#  42.32146737437456,
#  39.96562372770445,
#  37.86275050185819,
#  36.23981813522888,
#  34.29856178375389,
#  32.6931945423617]
